# %%
import pandas as pd

# %%
df=pd.read_excel('http://taanila.fi/kunnat.xlsx')
df.head()
# Out:
#        Kunta  Taajama-aste, %, 2017  Väkiluku, 2017  \
# 0       Akaa                   88.5           16769
# 1   Alajärvi                   60.7            9831
# 2  Alavieska                   52.6            2610
# 3     Alavus                   59.5           11713
# 4   Asikkala                   64.4            8248
#
#    Väkiluvun muutos edellisestä vuodesta, %, 2017  \
# 0                                            -0.9
# 1                                            -0.7
# 2                                            -1.1
# 3                                            -1.6
# 4                                            -0.9
#
#    Alle 15-vuotiaiden osuus väestöstä, %, 2017  \
# 0                                         18.0
# 1                                         17.7
# 2                                         19.6
# 3                                         17.0
# 4                                         14.2
#
#    15-64 -vuotiaiden osuus väestöstä, %, 2017  \
# ...

# %%
df.tail()
# Out:
#          Kunta  Taajama-aste, %, 2017  Väkiluku, 2017  \
# 306  Ylivieska                   86.0           15251
# 307   Ylöjärvi                   88.2           32878
# 308      Ypäjä                   40.8            2372
# 309     Ähtäri                   62.2            5906
# 310  Äänekoski                   75.4           19144
#
#      Väkiluvun muutos edellisestä vuodesta, %, 2017  \
# 306                                             0.3
# 307                                             0.2
# 308                                            -0.4
# 309                                            -1.3
# 310                                            -1.2
#
#      Alle 15-vuotiaiden osuus väestöstä, %, 2017  \
# 306                                         21.5
# 307                                         21.8
# 308                                         13.4
# 309                                         14.6
# 310                                         16.4
#
# ...

# %%
df.shape
# Out:
# (311, 32)

# %%
df.count()
# Out:
# Kunta                                                                                     311
# Taajama-aste, %, 2017                                                                     311
# Väkiluku, 2017                                                                            311
# Väkiluvun muutos edellisestä vuodesta, %, 2017                                            311
# Alle 15-vuotiaiden osuus väestöstä, %, 2017                                               311
# 15-64 -vuotiaiden osuus väestöstä, %, 2017                                                311
# Yli 64-vuotiaiden osuus väestöstä, %, 2017                                                311
# Ruotsinkielisten osuus väestöstä, %, 2017                                                 311
# Ulkomaan kansalaisten osuus väestöstä, %, 2017                                            311
# Syntyneiden enemmyys, henkilöä, 2017                                                      311
# ...

# %%
df[["Kunta", "Väkiluku, 2017"]].sort_values(by=["Väkiluku, 2017"]).head(10)
# Out:
#           Kunta  Väkiluku, 2017
# 257    Sottunga              92
# 122       Kökar             236
# 113    Kumlinge             314
# 147  Lumparland             395
# 303       Vårdö             430
# 7        Brändö             452
# 18         Geta             495
# 17        Föglö             532
# 145     Luhanka             734
# 136  Lestijärvi             789

# %%
df.sort_values(by=["Väkiluku, 2017"]).head(10)
# Out:
#           Kunta  Taajama-aste, %, 2017  Väkiluku, 2017  \
# 257    Sottunga                    0.0              92
# 122       Kökar                    0.0             236
# 113    Kumlinge                    0.0             314
# 147  Lumparland                    0.0             395
# 303       Vårdö                    0.0             430
# 7        Brändö                    0.0             452
# 18         Geta                    0.0             495
# 17        Föglö                    0.0             532
# 145     Luhanka                    0.0             734
# 136  Lestijärvi                   36.9             789
#
#      Väkiluvun muutos edellisestä vuodesta, %, 2017  \
# 257                                            -4.2
# 122                                            -4.1
# 113                                             1.9
# 147                                             2.6
# 303                                            -2.1
# ...

# %%
df[["Kunta", "Väkiluku, 2017"]].sort_values(by="Väkiluku, 2017", ascending=False).head(10)
# Out:
#          Kunta  Väkiluku, 2017
# 33    Helsinki          643272
# 11       Espoo          279044
# 268    Tampere          231853
# 291     Vantaa          223027
# 180       Oulu          201810
# 276      Turku          189669
# 63   Jyväskylä          140188
# 123      Lahti          119573
# 114     Kuopio          118209
# 201       Pori           84587
